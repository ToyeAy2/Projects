# %%
import pandas as pd
import numpy as np
import requests 
from bs4 import BeautifulSoup 
import csv 
import re

# %%
df = pd.read_csv("fortune27.csv")
df.head()
# Out:
#           Symbol                            Name   Category  \
# 0    RELIANCE.NS         Reliance Industries Ltd  Large Cap
# 1         TCS.NS  Tata Consultancy Services Ltd.  Large Cap
# 2    HDFCBANK.NS                  HDFC Bank Ltd.  Large Cap
# 3        INFY.NS                     Infosys Ltd  Large Cap
# 4  HINDUNILVR.NS          Hindustan Unilever Ltd  Large Cap
#
#                                                  Url
# 0  https://www.moneycontrol.com/news/business/eco...
# 1  https://www.moneycontrol.com/news/business/cry...
# 2  https://www.moneycontrol.com/news/business/mar...
# 3  https://www.moneycontrol.com/news/business/com...
# 4  https://www.moneycontrol.com/news/business/buy...

# %%
a = "Reliance Industries Ltd" #input("enter company name")

dff = df.loc[(df['Name'] == a).values]
dff = list(dff["Url"])
dff[0]
# Out:
# 'https://www.moneycontrol.com/news/business/economy/adani-group-in-pact-with-ballard-for-hydrogen-fuel-cells-in-india-8144311.html'

# %%
#Python program to scrape website  
#and save quotes from website 
import requests 
from bs4 import BeautifulSoup 
import csv 
import re

url_link = "https://news.google.com/search?q=tcs&hl=en-IN&gl=IN&ceid=IN%3Aen"
request = requests.get(url_link).text
 
Soup = BeautifulSoup(request, 'html.parser')
table1 = Soup.find_all('h3', attrs = {'class':'ipQwMb ekueJc RD0gLb'})
print(table1)
heading = table1
print("printing heading")
print(heading)
# Out:
# [<h3 class="ipQwMb ekueJc RD0gLb"><a class="DY5T1d RZIKme" href="./articles/CAIiELtP1ZlZMdxrGwKXYhpq47MqFggEKg4IACoGCAowxLQ_MNevCDD45Co?hl=en-IN&amp;gl=IN&amp;ceid=IN%3Aen">TCS shares down 6% in 5 days. Should you buy the IT stock?</a></h3>, <h3 class="ipQwMb ekueJc RD0gLb"><a class="DY5T1d RZIKme" href="....?hl=en-IN&amp;gl=IN&amp;ceid=IN%3Aen">TCS market cap doubles under Rajesh Gopinathan</a></h3>, <h3 class="ipQwMb ekueJc RD0gLb"><a class="DY5T1d RZIKme" href="./articles/CAIiEIGoP2HrZ-34Mfl7s2VDaeMqGQgEKhAIACoHCAowib-NCzDawJ8DMIbspwY?uo=CAUiigFodHRwczovL3plZW5ld3MuaW5kaWEuY29tL2NvbXBhbmllcy9pdC1iaWdnaWVzLXRjcy1pbmZvc3lzLXdpcHJvLWNvZ25pemFudC10by1hc2stZW1wbG95ZWVzLXRvLXdvcmstZnJvbS1vZmZpY2UtYWdhaW4tcmVwb3J0cy0yNDM4NzE4Lmh0bWzSAQA&amp;hl=en-IN&amp;gl=IN&amp;ceid=IN%3Aen">IT biggies TCS, Infosys, Wipro, Cognizant to ask employees to work from office again: Reports</a></h3>, <h3 class="ipQwMb ekueJc RD0gLb"><a class="DY5T1d RZIKme" href="./articles/CBMiaWh0dHBzOi8vd3d3LmJvYnNndWlkZS5
# ...

# %%
table1

# %%
lst[64:-6]
# Out:
# ['Billionaire Gautam Adani-led Adani Group has signed a non-binding pact with Nasdaq-listed Ballard Power Systems to evaluate a joint venture for investment in commercial production of hydrogen fuel cells for various mobility and industrial applications in India.',
#  'As per the memorandum of understanding, both parties will examine various options to cooperate, including potential collaboration for fuel cell manufacturing in India. Adani Enterprises’ newly formed arm Adani New Industries Limited (ANIL) will be housing the group’s green hydrogen initiatives.',
# ...

# %%
strng = " ".join(lst[64:-6])
strng
# Out:
# 'Billionaire Gautam Adani-led Adani Group has signed a non-binding pact with Nasdaq-listed Ballard Power Systems to evaluate a joint venture for investment in commercial production of hydrogen fuel cells for various mobility and industrial applications in India. As per the memorandum of understanding, both parties will examine various options to cooperate, including potential collaboration for fuel cell manufacturing in India. Adani Enterprises’ newly formed arm Adani New Industries Limited (ANIL) will be housing the group’s green hydrogen initiatives. “Our ability to build a world-class green hydrogen value chain will be critical in facilitating the energy transition and we are excited to partner with Ballard, a global leader in fuel cell technology, to create a shared fuel cell ecosystem in India. We will be deploying innovative use cases across our businesses with fuel cell trucks, mining equipment, marine vessels, off-road vehicles, and critical industrial power,” said Vneet S Ja
# ...
